# %%
import sys
import os
sys.path.append('../src')

from data_analysis import FinancialNewsAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Sample EDA code
def perform_eda(data_path):
    """Perform exploratory data analysis."""

# %%
# Initialize analyzer
analyzer = FinancialNewsAnalyzer(data_path)
    
    # 1. Descriptive Statistics
print("=== DESCRIPTIVE STATISTICS ===")
stats = analyzer.descriptive_statistics()
print(stats)

# %%
 # 2. Time Series Analysis
print("\n=== TIME SERIES ANALYSIS ===")
daily_counts = analyzer.time_series_analysis()
if daily_counts is not None:
    plt.figure(figsize=(12, 6))
    daily_counts.plot(title='Daily Publication Frequency')
    plt.xlabel('Date')
    plt.ylabel('Number of Articles')
    plt.tight_layout()
    plt.show()

# %%
    # 3. Text Analysis
print("\n=== TEXT ANALYSIS ===")
common_keywords = analyzer.text_analysis()
print("Top 20 Keywords:", common_keywords)
    
    # 4. Publisher Analysis
print("\n=== PUBLISHER ANALYSIS ===")
publisher_stats = analyzer.publisher_analysis()
print("Top Publishers:", publisher_stats.get('publisher_frequency', []).head(10))

if __name__ == "__main__":
    # This would be replaced with actual data path
    print("EDA Script - Replace with actual data path to run")
